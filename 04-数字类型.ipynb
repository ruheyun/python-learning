# %% [markdown]
# 数字类型：int, float, complex

# %%
num1 = 10  # int
num1
# Out:
# 10

# %%
num2 = 12.2  # float
num2
# Out:
# 12.2

# %%
num3 = 2 + 3j  # 复数
num3
# Out:
# (2+3j)

# %%
num4 = complex(2, 3)  # 复数的头部和虚部都是浮点型
num4
# Out:
# (2+3j)

# %%
a = 1.2
a = int(a)  # 强制类型转换为整数类型
a
# Out:
# 1

# %%
a = 1
a = float(a)  # 将整型转为浮点型
a
# Out:
# 1.0
