# %% [markdown]
# 元组与列表类似, 不同之处在于元组的元素不能修改, 元组使用小括号 ()

# %%
tup1 = ('hello', 'world', 2026)
tup1
# Out:
# ('hello', 'world', 2026)

# %% [markdown]
# 创建空元组时，用小括号表示，但是元组中只包含一个元素时，需要在元素后面添加逗号 , ，否则括号会被当作运算符使用

# %%
tup2 = ()
tup3 = (3)
tup4 = (3,)
print(type(tup2))
print(type(tup3))
print(type(tup4))
# Out:
# <class 'tuple'>
# <class 'int'>
# <class 'tuple'>

# %% [markdown]
# 元组可以索引和切片

# %%
tup1
# Out:
# ('hello', 'world', 2026)

# %%
tup1[0]
# Out:
# 'hello'

# %%
tup1[:2]
# Out:
# ('hello', 'world')

# %% [markdown]
# 元组不能修改

# %%
tup5 = (1, 2,3)
tup6 = (4, 5)
tup5[0] = 2  # 不能修改，会报错
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 tup5 = (1, 2,3)
#       2 tup6 = (4, 5)
# ----> 3 tup5[0] = 2
#
# TypeError: 'tuple' object does not support item assignment

# %%
tup7 = (1, 2, 3)
print(id(tup7))
tup7 = tup7 + tup6  # 通过拼接改变元组大小，但是元组所指向内存地址也会变化
print(id(tup7))
tup7
# Out:
# 3089886690624
# 3089886737760
# (1, 2, 3, 4, 5)
